# %% [markdown]
# # Kappa 4

# %% [markdown]
# ### 1. Wykorzystując bibliotekę scipy wygeneruj dwa zbiory danych w poniższych rozkładach:

# %% [markdown]
# #### b. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kappa4.html#scipy.stats.kappa4

# %%
from scipy.stats import kappa4
import matplotlib.pyplot as plt
import seaborn as sns
h, k = 0.1, 0
data = kappa4.rvs(h, k, size=1000)
print(data)
# Out:
# [ 8.83133124e-02 -6.48273205e-01  9.12336230e-01  7.70195280e-02
#   6.58176011e-01  2.47939288e+00  1.52412986e+00  4.11354553e-01
#   2.69734841e+00  8.92027031e-01  1.15391710e+00 -2.21984596e-01
#  -6.01343606e-01  2.43217659e+00 -1.09924477e-01 -4.52046040e-01
#  -1.81369536e+00  7.27238929e-01  2.41355253e+00  6.83372556e-01
#   2.98961484e+00  2.36021985e-02 -1.45012573e+00  4.74319142e-01
#   1.73601287e+00  1.61490057e+00 -9.39325383e-01  6.71909994e-01
#   6.37457655e-01 -9.63512822e-01  4.78832530e-01 -3.67967894e-01
#   3.61545416e-01  1.29249578e+00  9.03398134e-01 -4.25259834e-01
#   3.91586001e-01  5.19638485e+00  8.99602775e-01 -2.29518649e-01
#   4.51769014e-01  2.95408105e-02  6.59792912e-01  6.66267556e-01
#  -6.62472655e-01  1.17836180e-01  7.19719424e-01 -4.91269055e-01
#  -5.13934313e-01  1.03517573e+00 -8.06807043e-01 -3.39517948e-01
#   9.17545018e-01  1.58513593e+00 -1.33663905e-01  5.39066911e-01
# ...

# %% [markdown]
# ### 2. Wykorzystując bibliotekę matplotlib stwórz dla każdego zbioru:

# %% [markdown]
# #### a. wykresy skrzynkowe

# %%
fig4, ax4 = plt.subplots()
ax4.set_title('Hide Outlier Points')
ax4.boxplot(data, showfliers=False)
plt.show()

# %% [markdown]
# #### b. histogramy

# %%
plt.hist(data)
plt.title("Histogram")
plt.show()

# %% [markdown]
# ### 3. Wykorzystując bibliotekę seaborn stwórz dla każdego zbioru:

# %% [markdown]
# #### a. wykresy histogramów

# %%
sns.distplot(data)
plt.show()

# %% [markdown]
# #### b. wykresy jądrowych estymatorów gęstości

# %%
sns.kdeplot(data, shade=True, color="b")
plt.show()

# %% [markdown]
# #### c. wykresy gęstościowe

# %%
sns.distplot(data, kde=True, kde_kws={"color": "b", "shade":True })
plt.show()
